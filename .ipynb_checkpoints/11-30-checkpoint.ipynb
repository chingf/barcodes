# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import pearsonr
from scipy.special import softmax
from scipy.special import i0

# %%
# %matplotlib inline

# %%
np.random.seed(0)

# %% [markdown]
# # Helper functions

# %%
def relu(X):
    return np.maximum(0, X)

# %%
def make_bump(size, center):
    """
    Generates an exponential falloff.
    """
    
    assert(center < size)
    x = np.linspace(0, 100)
    halfbump = np.exp(-0.04*x)
    halfbump = halfbump/halfbump.max()
    bump = np.zeros(size)
    bump[:halfbump.size] = halfbump
    bump[-halfbump.size+1:] = halfbump[1:][::-1]
    offset = 0.
    bump = bump - offset
    bump[bump < 0] = 0
    bump /= bump.max()
    bump = np.roll(bump, center)
    return bump

plt.figure(figsize=(4,2))
plt.scatter(np.arange(201), make_bump(201, 28))
plt.title('Example Spatial Input')
plt.show()

# %% [markdown]
# # Dynamics Function

# %%
def get_activity(T, i, softmax_temp=1):
    """
    Runs T timesteps of dynamics given
    constant input i
    """
    
    x = x_prev = np.zeros(N)
    x_prev = i
    activities = []
    for t in range(T):
        x = J@(x_prev) + i
        x[b_start:b_end] = softmax(x[b_start:b_end]*softmax_temp)
        x[b_start:b_end] -= softmax_offset
        x = relu(x)
        x_prev = x
        activities.append(x)
    return activities

# %% [markdown]
# # Modifiable Parameters

# %%
n_spatial = 201
n_barcode = 1001
n_cache = 1
T = 10 # Number of timesteps to simulate
softmax_offset = 1/n_barcode
softmax_action_gain = int(n_barcode/50)

# %%
seed_locs = [int(n_spatial*0.3), int(n_spatial*0.5)]
print(f'Caches at locations {seed_locs}')
# Out:
# Caches at locations [60, 100]

# %% [markdown]
# # Network initializations

# %%
N = n_spatial + n_barcode + n_cache

# Defining useful indices
s_start = 0
s_end = n_spatial
b_start = s_end
b_end = b_start + n_barcode
c_start = b_end
c_end = -1
SEED = c_start

# %%
def make_J(seed_locs, verbose=True):
    J = np.zeros((N, N)) # (s,b,c) ordering

    # Set sparse spatial-barcode connections
#     for i in range(n_spatial):
#         # One-to-one
#         chosen_bs = np.array([i])
#         J[b_start + i, s_start_i] = 1
        
#         # Randomly select K
#         chosen_bs = np.random.choice(n_barcode, size=2, replace=False)
#         J[b_start + chosen_bs, s_start+i] = 1/chosen_bs.size

#         if verbose and (i in seed_locs):
#             plt.figure(figsize=(1,3))
#             plt.plot()
#             plt.title(f'Spatial cell {i}')
#             plt.xlabel('Connected Barcode Cells')
#             plt.show()
            
    # Random gaussian + decorrelation
    initial_J = np.random.randn(n_spatial, n_barcode)
    mask_J = (np.random.rand(n_spatial, n_barcode) < 0.005).astype(float) # % chance of on
    initial_J = np.multiply(initial_J, mask_J)
    final_J = initial_J.copy()
    for i in range(n_spatial):
        final_J[i] -= 0.5*initial_J[(i-1)%n_spatial]
        final_J[i] -= 0.5*initial_J[(i+1)%n_spatial]
        J[b_start:b_end, s_start + i] = final_J[i]
        if verbose and (i in seed_locs):
            plt.figure(figsize=(3, 1))
            plt.plot(final_J[i])
            plt.title(f'Spatial cell {i}')
            plt.xlabel('Connected Barcode Cells')
            plt.show()
            
    J[s_start:s_end, b_start:b_end] = J[b_start:b_end, s_start:s_end].T
    
    # Set barcode-cache connections
    for l in seed_locs:
        bump = make_bump(n_spatial, l)
        b_activations = J[b_start:b_end, s_start:s_end]@bump
        b_activations = softmax(b_activations*softmax_action_gain) - softmax_offset

        chosen_bs = np.argwhere(J[l, b_start:b_end]>0).flatten()
        #chosen_bs = np.argwhere(b_activations>0).flatten()

        J[b_start + chosen_bs, SEED] = 1
        J[SEED, b_start + chosen_bs] = 1
        if verbose:
            plt.figure(figsize=(3, 1))
            plt.plot(b_activations)
            plt.title(f'Barcode activations for spatial cell {l}')
            plt.show()
            
    return J

# %% [markdown]
# # Testing decorrelation

# %%
temp = softmax_action_gain

# %%
J = make_J(np.arange(n_spatial), verbose=False)

# %%
place_input_activity = []
barcode_activity_T1 = []
barcode_activity_T5 = []
barcode_activity_T20 = []
for loc in np.arange(n_spatial):
    _input = np.zeros(N)
    _input[s_start:s_end] = make_bump(n_spatial, loc)
    place_input_activity.append(_input[s_start:s_end])
    activity = get_activity(1, _input, softmax_temp=temp)[-1]
    barcode_activity_T1.append(activity[b_start:b_end])
    activity = get_activity(5, _input, softmax_temp=temp)[-1]
    barcode_activity_T5.append(activity[b_start:b_end])
    activity = get_activity(20, _input, softmax_temp=temp)[-1]
    barcode_activity_T20.append(activity[b_start:b_end])

fig, axs = plt.subplots(1, 4, figsize=(3*4,3))
axs[0].imshow(np.corrcoef(place_input_activity))
axs[0].set_title('Input Correlation')
axs[1].imshow(np.corrcoef(barcode_activity_T1))
axs[1].set_title('Barcode Correlation, t=1')
axs[2].imshow(np.corrcoef(barcode_activity_T5))
axs[2].set_title('Barcode Correlation, t=5')
axs[3].imshow(np.corrcoef(barcode_activity_T20))
axs[3].set_title('Barcode Correlation, t=20')
plt.show()

# %% [markdown]
# # Create actual J matrix

# %%
J = make_J(seed_locs)

# %% [markdown]
# # Capacity Plots-- Low softmax (No gain)

# %%
temp = 1

# %%
fig, ax = plt.subplots(figsize=(6.4*0.75, 4.8*0.25))
seed_cell_activity = []
for loc in np.arange(n_spatial):
    _input = np.zeros(N)
    _input[s_start:s_end] = make_bump(n_spatial, loc)
    activities = get_activity(T, _input, softmax_temp=temp)
    activity_T = activities[-1] # Select just the last timestep of dynamics
    seed_cell_activity.append(activity_T[SEED])
ax.plot(seed_cell_activity)
ax.set_title('Seed Cell Response')
ax.set_xlabel('Current Location')
ax.set_ylabel('Firing Rate')
ax.set_ylim(-0.1, 1.1)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(6.4*0.75, 4.8*0.25))
seed_cell_activity = []
for loc in np.arange(n_spatial):
    _input = np.zeros(N)
    _input[s_start:s_end] = make_bump(n_spatial, loc)
    activities = get_activity(T, _input, softmax_temp=temp)
    activity_T = activities[-1] # Select just the last timestep of dynamics
    seed_cell_activity.append(activity_T[s_start+50])
ax.plot(seed_cell_activity)
ax.set_title('Spatial Cell 50 Response')
ax.set_xlabel('Current Location')
ax.set_ylabel('Firing Rate')
ax.set_ylim(-0.1, 1.1)
plt.show()

# %% [markdown]
# # Capacity Plots-- With Barcode Gain

# %%
temp = softmax_action_gain

# %%
fig, ax = plt.subplots(figsize=(6.4*0.75, 4.8*0.25))
seed_cell_activity = []
for loc in np.arange(n_spatial):
    _input = np.zeros(N)
    _input[s_start:s_end] = make_bump(n_spatial, loc)
    activities = get_activity(T, _input, softmax_temp=temp)
    activity_T = activities[-1] # Select just the last timestep of dynamics
    seed_cell_activity.append(activity_T[SEED])
ax.plot(seed_cell_activity)
ax.set_title('Seed Cell Response')
ax.set_xlabel('Current Location')
ax.set_ylabel('Firing Rate')
ax.set_ylim(-0.1, 1.1)
plt.show()

# %% [markdown]
# # Memory Plots

# %%
test_loc = int(seed_locs[0] + (seed_locs[1]-seed_locs[0])*0.3)
seed_strength = 6
print(f'Testing memory at location {test_loc}')
print(f'Seed input is of strength {seed_strength}')
# Out:
# Testing memory at location 72
# Seed input is of strength 6

# %%
spatial_input = make_bump(n_spatial, test_loc)
fig, axs = plt.subplots(1, 2, figsize=(6.4, 4.8*0.25))
axs[0].plot(spatial_input, color='k')
axs[1].scatter([0], [1], color='k')
axs[0].set_title('Spatial Cell Input')
axs[1].set_title('Content Cell Input')
axs[1].set_xticks([0], ['Seed'])
for ax in axs:
    ax.set_ylim(-.1, 1.1)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(6.4*0.75, 4.8*0.5))
_input = np.zeros(N)
_input[s_start:s_end] = make_bump(n_spatial, test_loc)
_input[SEED] = seed_strength
activities = get_activity(T, _input, softmax_temp=1)
activity_T = activities[-1]
ax.plot(activity_T[s_start:s_end])
ax.set_xlabel('Spatial cell')
ax.set_ylabel('Firing Rate')
ax.axvline(test_loc, color='gray', linestyle='--')
plt.suptitle(f'At Location {test_loc}')
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(6.4*0.75, 4.8*0.5))
corrs = []
for spatial_loc in np.arange(n_spatial):
    barcode = np.zeros(n_barcode)
    if spatial_loc not in space_to_bar.keys():
        corr = 0
    else:
        for b in space_to_bar[spatial_loc]:
            barcode[b] = 1
        corr = np.dot(activity_T[b_start:b_end], barcode)
    corrs.append(corr)
ax.bar(np.arange(n_spatial), corrs, width=2)
ax.set_ylabel('Barcode-Place Correlation')
ax.set_xlabel('Place Cell')
ax.set_title(f'At Location {test_loc}')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [23], line 5
#       3 for spatial_loc in np.arange(n_spatial):
#       4     barcode = np.zeros(n_barcode)
# ----> 5     if spatial_loc not in space_to_bar.keys():
#       6         corr = 0
#       7     else:
#
# NameError: name 'space_to_bar' is not defined
