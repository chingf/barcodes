# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Helper functions

# %%
def relu_cap(x, b=0):
    return np.clip(x-b, 0, 1)


def relu(x, b=0):
    return np.clip(x-b, 0, np.inf)

def binary(x, b=0):
    return (x>b).astype(float)

def normalize(x):
    return (x -np.mean(x, axis=1, keepdims=True))/ (1e-8+np.std(x, axis=1, keepdims=True))

def sigmoid(x, b=0):
    return 1 / (1 + np.exp(-(x-b)))

# %%
def run_dynamics(W, inputs,  dt=0.1, b=0.0, steps=100):
    acts = np.zeros([num_states, N_bar])
    for s in range(steps):
        dxdt = np.matmul(acts, W) + inputs*(s==0)
        preacts = (1-dt)*acts + dt*dxdt
        acts = relu(normalize(preacts), b=b)# p=p)    

    
    return normalize(preacts), acts

# %%
def pairwise_correlations_centered(x):
    return np.corrcoef(x-np.mean(x, 0))

# %%
def distance(a, b, maximum):
    dist = np.abs(a - b)
    dist = min(dist, np.abs(maximum-dist))
    return dist

# %% [markdown]
# # Parameters and Setup

# %%
N_inp = 5000
N_bar = 5000

num_states = 100
decay_constant = 0.2
steps = 100
dt = 0.1

cache_states = [20,  60, 30, 70, 90]

b=0.1

rec_strength = 1.2
input_strength = 1.0

# %%
inputs = np.zeros([num_states, N_inp])
for s in range(num_states):
    peak = int(s / float(num_states) * N_inp)
    for n in range(N_inp):
        dist = distance(n, peak, N_inp)
        inputs[s, n] = np.exp(-(dist/(N_inp*decay_constant)))
input_act = relu(normalize(inputs), b = b)

# %%
plt.figure(figsize=(10,5))
plt.imshow(input_act, aspect='auto')
plt.show()

# %%
W_reconstruct = np.zeros([N_inp, N_bar])
rand_J = np.random.randn(N_bar, N_bar)
#rand_J = np.tril(rand_J) + np.tril(rand_J, -1).T
W_rec = rec_strength*(rand_J / np.sqrt(N_bar))# - rec_strength*(0.05 / np.sqrt(N_bar))
W_fantasy = np.zeros([N_bar])

# %% [markdown]
# # Initial activity profiles

# %%
plt.imshow(input_act, vmin=0,  aspect='auto')
plt.xlabel("neuron")
plt.ylabel("location")
plt.colorbar()
plt.title("input activity (non-recurrent mode)")
plt.show()

# %%
plt.imshow(pairwise_correlations_centered(input_act), vmin=0, vmax=1)
plt.colorbar()
plt.title("pairwise correlations of input activity (non-recurrent mode)")
plt.show()

# %% [markdown]
# # Get barcodes

# %%
preacts, acts = run_dynamics(W_rec, input_strength*inputs+0*W_fantasy, b=b)# relu_cap_adaptive2(0.0*W_fantasy+acts*(1-time_length) + time_length*np.matmul(acts, W_rec)+time_length*inp_strength*inputs, b=b)# p=p)

# %%
plt.imshow(acts, vmin=0, vmax=5, aspect='auto')
plt.xlabel("neuron")
plt.ylabel("location")
plt.colorbar()
plt.title("barcode activity (recurrent mode)")
plt.show()

# %%
base_barcodes = acts.copy()

# %%
print('sparsity', np.mean(acts>0))    
plt.imshow(pairwise_correlations_centered(acts), vmin=0, vmax=1)
plt.colorbar()
plt.title("pairwise correlations of barcode activity (recurrent mode)")
plt.show()
# Out:
# sparsity 0.050892

# %%
acts_normalized = normalize(acts)
inputs_normalized = normalize(input_act)
corrs = [np.corrcoef(acts_normalized[i], inputs_normalized[i])[0, 1] for i in range(num_states)]
plt.title("Correlations between place and barcode activity at each state")
plt.xlabel("Location")
plt.plot(corrs)
plt.show()

# %% [markdown]
# # Create caches

# %%
narrow_search_factor = -0.05
wide_search_factor = 0.1
suppress_factor = -0.5
lr = 1.0
for cache_state in cache_states:
    
    fig, ax = plt.subplots(1, 5, figsize=(25, 5))
    
    print("Now I just cached at location:", cache_state)

    preacts, acts = run_dynamics(W_rec, input_strength*inputs + suppress_factor*W_fantasy, b=b)
    
        
    W_fantasy += acts[cache_state]
    act = acts[cache_state:cache_state+1]
    preact = preacts[cache_state:cache_state+1]
    delta_W = np.matmul(act.transpose(), act)
    W_rec += lr * delta_W / N_bar
    W_reconstruct += inputs[cache_state].reshape(-1, 1) @ acts[cache_state].reshape(1, -1)
    
    #W_reconstruct += inputs[cache_state].reshape(-1, 1) @ inputs[cache_state].reshape(1, -1)#acts[cache_state].reshape(1, -1)
    
    
    preacts, acts = run_dynamics(W_rec, input_strength*inputs+suppress_factor*W_fantasy, b=b) 
    ax[0].set_title("pairwise correlations of barcode activity")
    ax[0].imshow(pairwise_correlations_centered(acts), vmin=0, vmax=1)

    preacts, acts = run_dynamics(W_rec, input_strength*inputs+wide_search_factor*W_fantasy, b=b) 
    ax[1].set_title("pairwise correlations of fantasy activity (wide search)")
    ax[1].imshow(pairwise_correlations_centered(acts), vmin=0, vmax=1)
    
    reconstruct = np.matmul(acts, W_reconstruct.transpose())
    #reconstruct = np.matmul(inputs, W_reconstruct.transpose())
    ax[2].set_xlabel("neuron")
    ax[2].set_ylabel("location")
    ax[2].imshow(reconstruct, aspect='auto')
    ax[2].set_title("Place field reconstruction during fantasy (wide search)")
    
    
    preacts, acts = run_dynamics(W_rec, input_strength*inputs+narrow_search_factor*W_fantasy, b=b) 
    ax[3].set_title("pairwise correlations of fantasy activity (narrow search)")
    ax[3].imshow(pairwise_correlations_centered(acts), vmin=0, vmax=1)
    
    
    reconstruct = np.matmul(acts, W_reconstruct.transpose())
    #reconstruct = np.matmul(inputs, W_reconstruct.transpose())
    ax[4].set_xlabel("neuron")
    ax[4].set_ylabel("location")
    ax[4].imshow(reconstruct, aspect='auto')
    ax[4].set_title("Place field reconstruction during fantasy (narrow search)")
    plt.show()
# Out:
# Now I just cached at location: 20
# Now I just cached at location: 60
# Now I just cached at location: 30
# Now I just cached at location: 70
# Now I just cached at location: 90

# %% [markdown]
# # Add: place fields unaffected

# %%
preacts, acts = run_dynamics(W_rec, input_strength*inputs+suppress_factor*W_fantasy, b=b, steps=10)
base_correlations = np.corrcoef(acts, base_barcodes)[:100,100:]
plt.figure()
plt.imshow(base_correlations)
plt.colorbar()
plt.show()

base_correlations = np.corrcoef(acts)
plt.figure()
plt.imshow(base_correlations)
plt.colorbar()
plt.show()

# %% [markdown]
# # Add: base barcode comparison

# %%
preacts, acts = run_dynamics(W_rec, input_strength*inputs+suppress_factor*W_fantasy, b=b)
base_correlations = np.corrcoef(acts, base_barcodes)[:100,100:]
plt.figure()
plt.imshow(base_correlations)
plt.show()

# %%
preacts, acts = run_dynamics(W_rec, input_strength*inputs+wide_search_factor*W_fantasy, b=b) 
base_correlations_wide = np.corrcoef(acts, base_barcodes)[:100,100:]
plt.figure()
plt.imshow(base_correlations_wide)
plt.show()

# %%
preacts, acts = run_dynamics(W_rec, input_strength*inputs+narrow_search_factor*W_fantasy, b=b) 
base_correlations_narrow = np.corrcoef(acts, base_barcodes)[:100,100:]
plt.figure()
plt.imshow(base_correlations_narrow)
plt.colorbar()
plt.show()

# %%
v = np.argmax(base_correlations_narrow, axis=1)

attractor_dist = []
opt_attractor_dist = []
attractor_locs = []
attractor_validity = []
for loc, _v in enumerate(v):
    _opt_dist = min([distance(loc, c, num_states) for c in cache_states])
    opt_attractor_dist.append(_opt_dist)
    if _v in cache_states:
        attractor_dist.append(distance(loc, _v, num_states))
        attractor_locs.append(_v)
        attractor_validity.append(1)
    elif _v == loc:
        attractor_dist.append(np.nan)
        attractor_locs.append(np.nan)
        attractor_validity.append(0)
    else:
        attractor_dist.append(np.nan)
        attractor_locs.append(np.nan)
        attractor_validity.append(-1)
attractor_dist = np.array(attractor_dist)
attractor_locs = np.array(attractor_locs)
attractor_validity = np.array(attractor_validity)
opt_attractor_dist = np.array(opt_attractor_dist)

# %%
# How many are snapped to an attractor?
plt.figure()
valid = np.sum(attractor_validity==1)/attractor_validity.size
self = np.sum(attractor_validity==0)/attractor_validity.size
invalid = np.sum(attractor_validity==-1)/attractor_validity.size
plt.bar(['Valid', 'Self', 'Invalid'], [valid, self, invalid])
plt.title('Attractor Validity')
plt.show()

# %%
import pandas as pd
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [114], line 2
#       1 import pandas as pd
# ----> 2 import seaborn as sns
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
# How many are snapped to an attractor, as a function of nearest attractor?
xs = []; ys = []; labels = []
for _opt_dist in np.sort(np.unique(opt_attractor_dist)):
    idxs = opt_attractor_dist==_opt_dist
    _validity = attractor_validity[idxs]
    valid = np.sum(_validity==1)/_validity.size
    self = np.sum(_validity==0)/_validity.size
    invalid = np.sum(_validity==-1)/_validity.size
    xs.extend([_opt_dist]*3)
    ys.extend([valid, self, invalid])
    labels.extend(['Valid', 'Self', 'Invalid'])
df = pd.DataFrame({'Nearest Attractor': xs, 'Outcome Prob': ys, 'Outcome': labels})
sns.lineplot(x='Nearest Attractor', y='Outcome Prob', hue='Outcome', data=df)
plt.show()

# %%
# Of those that snap to an attractor, which ones do they snap to
plt.figure()
counts = np.zeros(len(cache_states))
for idx, cache_state in enumerate(cache_states):
    counts[idx] = np.sum(locs==cache_state)
plt.bar(cache_states, counts, width=2.)
plt.show()

# %%
# Of those that snap to an attractor, how far is the chosen attractor from the optimal?
plt.figure()
plt.scatter()
counts = np.zeros(len(cache_states))
for idx, cache_state in enumerate(cache_states):
    counts[idx] = np.sum(locs==cache_state)
    distance(loc, _v, num_states)
plt.bar(cache_states, counts, width=2.)
plt.show()

# %% [markdown]
# # Add: sharpness plots

# %%
v = np.max(base_correlations_wide, axis=1)
plt.figure()
plt.plot(v)
plt.ylabel('Max Correlation value')
plt.xlabel('Location')
plt.show()

# %%
v = np.argmax(base_correlations_wide, axis=1)
plt.figure()
plt.plot(v)
plt.ylabel('Location of Attractor')
plt.xlabel('Current Location')
plt.ylim(0)
plt.show()

# %%
dists = []
locs = []
for loc, _v in enumerate(v):
    if _v in cache_states:
        dist = distance(loc, _v, num_states)
        locs.append(_v)
    elif _v == loc:
        dist = 0
    else:
        dist = np.nan
    dists.append(dist)

# %%
plt.figure(figsize=(3,2))
plt.plot(dists)
plt.show()

# %%
plt.figure(figsize=(3,2))
plt.hist(dists)
plt.show()

# %%
plt.figure(figsize=(3,2))
plt.hist(locs)
plt.show()

# %%
v = np.max(base_correlations_narrow, axis=1)
plt.figure(figsize=(3,2))
plt.plot(v)
plt.ylabel('Max Correlation value')
plt.xlabel('Location')
plt.show()

# %%
v = np.argmax(base_correlations_narrow, axis=1)
plt.figure(figsize=(3,2))
plt.plot(v)
plt.ylabel('Location of Attractor')
plt.xlabel('Current Location')
plt.ylim(0)
plt.show()

# %%
dists = []
locs = []
for loc, _v in enumerate(v):
    if _v in cache_states:
        dist = distance(loc, _v, num_states)
        locs.append(_v)
    elif _v == loc:
        dist = 0
    else:
        dist = np.nan
    dists.append(dist)

# %%
plt.figure(figsize=(3,2))
plt.plot(dists)
plt.show()

# %%
plt.figure(figsize=(3,2))
plt.hist(dists)
plt.show()

# %%
plt.figure(figsize=(3,2))
plt.hist(locs)
plt.show()

# %% [markdown]
# # Forgetting 20

# %%
preacts, acts = run_dynamics(W_rec, input_strength*inputs+wide_search_factor*W_fantasy - base_barcodes[20], b=b) 
plt.figure()
plt.imshow(np.corrcoef(acts, base_barcodes)[:100,100:])
plt.show()

# %%
preacts, acts = run_dynamics(W_rec, input_strength*inputs+wide_search_factor*W_fantasy - 0.1*base_barcodes[20], b=b) 
plt.figure()
plt.imshow(np.corrcoef(acts, base_barcodes)[:100,100:])
plt.show()

# %%
plt.figure()
plt.imshow(np.corrcoef(base_barcodes))
plt.show()

# %%
preacts, acts = run_dynamics(W_rec, input_strength*inputs+0*W_fantasy - base_barcodes[20], b=b) 
plt.figure()
plt.imshow(np.corrcoef(acts, base_barcodes)[:100,100:])
plt.show()
